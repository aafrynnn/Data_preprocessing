# %% [markdown]
# ## Installing required libraries

# %%
#!pip install scikit-learn
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./.local/lib/python3.10/site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: pandas>=1.2 in ./.local/lib/python3.10/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.local/lib/python3.10/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/tljh/user/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading the merged dataframe

# %% [markdown]
# ## Dataset merged and

# %%
df=pd.read_csv("df_admissions.csv")
df
# Out:
#         Unnamed: 0  subject_id      hadm_id            admittime  \
# 0                0    10000100  58594204243  2019-06-26 13:20:00
# 1                1    10000562  60707883031  2016-06-02 09:24:00
# 2                2    10000671  67252991505  2019-05-14 20:20:00
# 3                3    10000683  29770490036  2015-05-12 18:28:00
# 4                4    10000683  21514546148  2015-05-28 14:04:00
# ...            ...         ...          ...                  ...
# 972842      972842    99999731  37382428249  2009-11-24 12:50:00
# 972843      972843    99999731  58311570862  2010-06-28 15:23:00
# 972844      972844    99999731  55258667078  2010-11-20 13:01:00
# 972845      972845    99999856  39743800534  2019-09-21 08:20:00
# 972846      972846    99999997  48836056566  2018-02-13 22:44:00
#
#                   dischtime deathtime  admission_type  admit_provider_id  \
# 0       2019-07-05 12:47:00       NaN             NaN                NaN
# 1       2016-06-04 15:11:00       NaN             NaN                NaN
# 2       2019-05-15 13:09:00       NaN             NaN                NaN
# 3       2015-05-17 15:55:00       NaN             NaN                NaN
# 4       2015-06-03 19:03:00       NaN             NaN                NaN
# ...                     ...       ...             ...                ...
# 972842  2009-11-25 18:50:00       NaN             NaN                NaN
# 972843  2010-06-29 19:42:00       NaN             NaN                NaN
# 972844  2010-11-21 18:45:00       NaN             NaN                NaN
# 972845  2019-09-23 15:45:00       NaN             NaN                NaN
# 972846  2018-02-15 14:53:00       NaN             NaN                NaN
#
#          admission_location discharge_location  ...  \
# 0         PHYSIC OFC/CLINIC     HOME SELF CARE  ...
# 1       NON-HC FACILITY POO     HOME SELF CARE  ...
# 2       NON-HC FACILITY POO     HOME SELF CARE  ...
# 3        TRANSFER FROM HOSP     HOME SELF CARE  ...
# 4       NON-HC FACILITY POO     HOME SELF CARE  ...
# ...                     ...                ...  ...
# 972842         Not Recorded     HOME SELF CARE  ...
# 972843  NON-HC FACILITY POO     HOME SELF CARE  ...
# 972844  NON-HC FACILITY POO     HOME SELF CARE  ...
# 972845  NON-HC FACILITY POO     HOME SELF CARE  ...
# 972846  NON-HC FACILITY POO     HOME SELF CARE  ...
#
#                               race  edregtime  edouttime hospital_expire_flag  \
# 0       African American  or Black        NaN        NaN                    0
# 1       African American  or Black        NaN        NaN                    0
# 2       African American  or Black        NaN        NaN                    0
# 3               Caucasian or White        NaN        NaN                    0
# 4               Caucasian or White        NaN        NaN                    0
# ...                            ...        ...        ...                  ...
# 972842  African American  or Black        NaN        NaN                    0
# 972843  African American  or Black        NaN        NaN                    0
# 972844  African American  or Black        NaN        NaN                    0
# 972845          Caucasian or White        NaN        NaN                    0
# 972846          Caucasian or White        NaN        NaN                    0
#
#           subject_id_hadm_id  \
# 0       10000100_58594204243
# 1       10000562_60707883031
# 2       10000671_67252991505
# 3       10000683_29770490036
# 4       10000683_21514546148
# ...                      ...
# 972842  99999731_37382428249
# 972843  99999731_58311570862
# 972844  99999731_55258667078
# 972845  99999856_39743800534
# 972846  99999997_48836056566
#
#                                                long_title  icd_code  \
# 0                                        Abscess of liver     K75.0
# 1                      Long term (current) use of insulin     Z79.4
# 2                                         Epigastric pain    R10.13
# 3                                            Not Recorded     272.4
# 4                                            Not Recorded    305.00
# ...                                                   ...       ...
# 972842                                       Not Recorded     585.9
# 972843                                       Not Recorded    255.42
# 972844                                       Not Recorded    276.51
# 972845                    Unspecified atrial fibrillation    I48.91
# 972846  Age-related osteoporosis without current patho...     M81.0
#
#        first_careunit last_careunit       los
# 0                 NaN           NaN       NaN
# 1                 NaN           NaN       NaN
# 2                 NaN           NaN       NaN
# 3          5E ICU EUH    5E ICU EUH  0.207338
# 4                 NaN           NaN       NaN
# ...               ...           ...       ...
# 972842            NaN           NaN       NaN
# 972843            NaN           NaN       NaN
# 972844            NaN           NaN       NaN
# 972845            NaN           NaN       NaN
# 972846            NaN           NaN       NaN
#
# [972847 rows x 23 columns]

# %% [markdown]
# ### Removing the extra column

# %%
df=df.drop("Unnamed: 0", axis=1)
df
# Out:
#         subject_id      hadm_id            admittime            dischtime  \
# 0         10000100  58594204243  2019-06-26 13:20:00  2019-07-05 12:47:00
# 1         10000562  60707883031  2016-06-02 09:24:00  2016-06-04 15:11:00
# 2         10000671  67252991505  2019-05-14 20:20:00  2019-05-15 13:09:00
# 3         10000683  29770490036  2015-05-12 18:28:00  2015-05-17 15:55:00
# 4         10000683  21514546148  2015-05-28 14:04:00  2015-06-03 19:03:00
# ...            ...          ...                  ...                  ...
# 972842    99999731  37382428249  2009-11-24 12:50:00  2009-11-25 18:50:00
# 972843    99999731  58311570862  2010-06-28 15:23:00  2010-06-29 19:42:00
# 972844    99999731  55258667078  2010-11-20 13:01:00  2010-11-21 18:45:00
# 972845    99999856  39743800534  2019-09-21 08:20:00  2019-09-23 15:45:00
# 972846    99999997  48836056566  2018-02-13 22:44:00  2018-02-15 14:53:00
#
#        deathtime  admission_type  admit_provider_id   admission_location  \
# 0            NaN             NaN                NaN    PHYSIC OFC/CLINIC
# 1            NaN             NaN                NaN  NON-HC FACILITY POO
# 2            NaN             NaN                NaN  NON-HC FACILITY POO
# 3            NaN             NaN                NaN   TRANSFER FROM HOSP
# 4            NaN             NaN                NaN  NON-HC FACILITY POO
# ...          ...             ...                ...                  ...
# 972842       NaN             NaN                NaN         Not Recorded
# 972843       NaN             NaN                NaN  NON-HC FACILITY POO
# 972844       NaN             NaN                NaN  NON-HC FACILITY POO
# 972845       NaN             NaN                NaN  NON-HC FACILITY POO
# 972846       NaN             NaN                NaN  NON-HC FACILITY POO
#
#        discharge_location            insurance  ...  \
# 0          HOME SELF CARE           MEDICARE A  ...
# 1          HOME SELF CARE             MEDICAID  ...
# 2          HOME SELF CARE             SELF PAY  ...
# 3          HOME SELF CARE         MANAGED CARE  ...
# 4          HOME SELF CARE         MANAGED CARE  ...
# ...                   ...                  ...  ...
# 972842     HOME SELF CARE         MANAGED CARE  ...
# 972843     HOME SELF CARE         MANAGED CARE  ...
# 972844     HOME SELF CARE         MANAGED CARE  ...
# 972845     HOME SELF CARE             MEDICARE  ...
# 972846     HOME SELF CARE  MEDICARE/BLUE CROSS  ...
#
#                               race  edregtime edouttime  hospital_expire_flag  \
# 0       African American  or Black        NaN       NaN                     0
# 1       African American  or Black        NaN       NaN                     0
# 2       African American  or Black        NaN       NaN                     0
# 3               Caucasian or White        NaN       NaN                     0
# 4               Caucasian or White        NaN       NaN                     0
# ...                            ...        ...       ...                   ...
# 972842  African American  or Black        NaN       NaN                     0
# 972843  African American  or Black        NaN       NaN                     0
# 972844  African American  or Black        NaN       NaN                     0
# 972845          Caucasian or White        NaN       NaN                     0
# 972846          Caucasian or White        NaN       NaN                     0
#
#           subject_id_hadm_id  \
# 0       10000100_58594204243
# 1       10000562_60707883031
# 2       10000671_67252991505
# 3       10000683_29770490036
# 4       10000683_21514546148
# ...                      ...
# 972842  99999731_37382428249
# 972843  99999731_58311570862
# 972844  99999731_55258667078
# 972845  99999856_39743800534
# 972846  99999997_48836056566
#
#                                                long_title icd_code  \
# 0                                        Abscess of liver    K75.0
# 1                      Long term (current) use of insulin    Z79.4
# 2                                         Epigastric pain   R10.13
# 3                                            Not Recorded    272.4
# 4                                            Not Recorded   305.00
# ...                                                   ...      ...
# 972842                                       Not Recorded    585.9
# 972843                                       Not Recorded   255.42
# 972844                                       Not Recorded   276.51
# 972845                    Unspecified atrial fibrillation   I48.91
# 972846  Age-related osteoporosis without current patho...    M81.0
#
#        first_careunit last_careunit       los
# 0                 NaN           NaN       NaN
# 1                 NaN           NaN       NaN
# 2                 NaN           NaN       NaN
# 3          5E ICU EUH    5E ICU EUH  0.207338
# 4                 NaN           NaN       NaN
# ...               ...           ...       ...
# 972842            NaN           NaN       NaN
# 972843            NaN           NaN       NaN
# 972844            NaN           NaN       NaN
# 972845            NaN           NaN       NaN
# 972846            NaN           NaN       NaN
#
# [972847 rows x 22 columns]

# %% [markdown]
# ### Dropping duplicates in the data

# %% [markdown]
# There could be duplicates in the dataframe, so removing that.

# %%
df=df.drop_duplicates()
df
# Out:
#         subject_id      hadm_id            admittime            dischtime  \
# 0         10000100  58594204243  2019-06-26 13:20:00  2019-07-05 12:47:00
# 1         10000562  60707883031  2016-06-02 09:24:00  2016-06-04 15:11:00
# 2         10000671  67252991505  2019-05-14 20:20:00  2019-05-15 13:09:00
# 3         10000683  29770490036  2015-05-12 18:28:00  2015-05-17 15:55:00
# 4         10000683  21514546148  2015-05-28 14:04:00  2015-06-03 19:03:00
# ...            ...          ...                  ...                  ...
# 972842    99999731  37382428249  2009-11-24 12:50:00  2009-11-25 18:50:00
# 972843    99999731  58311570862  2010-06-28 15:23:00  2010-06-29 19:42:00
# 972844    99999731  55258667078  2010-11-20 13:01:00  2010-11-21 18:45:00
# 972845    99999856  39743800534  2019-09-21 08:20:00  2019-09-23 15:45:00
# 972846    99999997  48836056566  2018-02-13 22:44:00  2018-02-15 14:53:00
#
#        deathtime  admission_type  admit_provider_id   admission_location  \
# 0            NaN             NaN                NaN    PHYSIC OFC/CLINIC
# 1            NaN             NaN                NaN  NON-HC FACILITY POO
# 2            NaN             NaN                NaN  NON-HC FACILITY POO
# 3            NaN             NaN                NaN   TRANSFER FROM HOSP
# 4            NaN             NaN                NaN  NON-HC FACILITY POO
# ...          ...             ...                ...                  ...
# 972842       NaN             NaN                NaN         Not Recorded
# 972843       NaN             NaN                NaN  NON-HC FACILITY POO
# 972844       NaN             NaN                NaN  NON-HC FACILITY POO
# 972845       NaN             NaN                NaN  NON-HC FACILITY POO
# 972846       NaN             NaN                NaN  NON-HC FACILITY POO
#
#        discharge_location            insurance  ...  \
# 0          HOME SELF CARE           MEDICARE A  ...
# 1          HOME SELF CARE             MEDICAID  ...
# 2          HOME SELF CARE             SELF PAY  ...
# 3          HOME SELF CARE         MANAGED CARE  ...
# 4          HOME SELF CARE         MANAGED CARE  ...
# ...                   ...                  ...  ...
# 972842     HOME SELF CARE         MANAGED CARE  ...
# 972843     HOME SELF CARE         MANAGED CARE  ...
# 972844     HOME SELF CARE         MANAGED CARE  ...
# 972845     HOME SELF CARE             MEDICARE  ...
# 972846     HOME SELF CARE  MEDICARE/BLUE CROSS  ...
#
#                               race  edregtime edouttime  hospital_expire_flag  \
# 0       African American  or Black        NaN       NaN                     0
# 1       African American  or Black        NaN       NaN                     0
# 2       African American  or Black        NaN       NaN                     0
# 3               Caucasian or White        NaN       NaN                     0
# 4               Caucasian or White        NaN       NaN                     0
# ...                            ...        ...       ...                   ...
# 972842  African American  or Black        NaN       NaN                     0
# 972843  African American  or Black        NaN       NaN                     0
# 972844  African American  or Black        NaN       NaN                     0
# 972845          Caucasian or White        NaN       NaN                     0
# 972846          Caucasian or White        NaN       NaN                     0
#
#           subject_id_hadm_id  \
# 0       10000100_58594204243
# 1       10000562_60707883031
# 2       10000671_67252991505
# 3       10000683_29770490036
# 4       10000683_21514546148
# ...                      ...
# 972842  99999731_37382428249
# 972843  99999731_58311570862
# 972844  99999731_55258667078
# 972845  99999856_39743800534
# 972846  99999997_48836056566
#
#                                                long_title icd_code  \
# 0                                        Abscess of liver    K75.0
# 1                      Long term (current) use of insulin    Z79.4
# 2                                         Epigastric pain   R10.13
# 3                                            Not Recorded    272.4
# 4                                            Not Recorded   305.00
# ...                                                   ...      ...
# 972842                                       Not Recorded    585.9
# 972843                                       Not Recorded   255.42
# 972844                                       Not Recorded   276.51
# 972845                    Unspecified atrial fibrillation   I48.91
# 972846  Age-related osteoporosis without current patho...    M81.0
#
#        first_careunit last_careunit       los
# 0                 NaN           NaN       NaN
# 1                 NaN           NaN       NaN
# 2                 NaN           NaN       NaN
# 3          5E ICU EUH    5E ICU EUH  0.207338
# 4                 NaN           NaN       NaN
# ...               ...           ...       ...
# 972842            NaN           NaN       NaN
# 972843            NaN           NaN       NaN
# 972844            NaN           NaN       NaN
# 972845            NaN           NaN       NaN
# 972846            NaN           NaN       NaN
#
# [972847 rows x 22 columns]

# %% [markdown]
# We want to remove the rows where all values are missing.

# %%
#Remove rows with missing values
df=df.dropna(how='all')
df
# Out:
#         subject_id      hadm_id            admittime            dischtime  \
# 0         10000100  58594204243  2019-06-26 13:20:00  2019-07-05 12:47:00
# 1         10000562  60707883031  2016-06-02 09:24:00  2016-06-04 15:11:00
# 2         10000671  67252991505  2019-05-14 20:20:00  2019-05-15 13:09:00
# 3         10000683  29770490036  2015-05-12 18:28:00  2015-05-17 15:55:00
# 4         10000683  21514546148  2015-05-28 14:04:00  2015-06-03 19:03:00
# ...            ...          ...                  ...                  ...
# 972842    99999731  37382428249  2009-11-24 12:50:00  2009-11-25 18:50:00
# 972843    99999731  58311570862  2010-06-28 15:23:00  2010-06-29 19:42:00
# 972844    99999731  55258667078  2010-11-20 13:01:00  2010-11-21 18:45:00
# 972845    99999856  39743800534  2019-09-21 08:20:00  2019-09-23 15:45:00
# 972846    99999997  48836056566  2018-02-13 22:44:00  2018-02-15 14:53:00
#
#        deathtime  admission_type  admit_provider_id   admission_location  \
# 0            NaN             NaN                NaN    PHYSIC OFC/CLINIC
# 1            NaN             NaN                NaN  NON-HC FACILITY POO
# 2            NaN             NaN                NaN  NON-HC FACILITY POO
# 3            NaN             NaN                NaN   TRANSFER FROM HOSP
# 4            NaN             NaN                NaN  NON-HC FACILITY POO
# ...          ...             ...                ...                  ...
# 972842       NaN             NaN                NaN         Not Recorded
# 972843       NaN             NaN                NaN  NON-HC FACILITY POO
# 972844       NaN             NaN                NaN  NON-HC FACILITY POO
# 972845       NaN             NaN                NaN  NON-HC FACILITY POO
# 972846       NaN             NaN                NaN  NON-HC FACILITY POO
#
#        discharge_location            insurance  ...  \
# 0          HOME SELF CARE           MEDICARE A  ...
# 1          HOME SELF CARE             MEDICAID  ...
# 2          HOME SELF CARE             SELF PAY  ...
# 3          HOME SELF CARE         MANAGED CARE  ...
# 4          HOME SELF CARE         MANAGED CARE  ...
# ...                   ...                  ...  ...
# 972842     HOME SELF CARE         MANAGED CARE  ...
# 972843     HOME SELF CARE         MANAGED CARE  ...
# 972844     HOME SELF CARE         MANAGED CARE  ...
# 972845     HOME SELF CARE             MEDICARE  ...
# 972846     HOME SELF CARE  MEDICARE/BLUE CROSS  ...
#
#                               race  edregtime edouttime  hospital_expire_flag  \
# 0       African American  or Black        NaN       NaN                     0
# 1       African American  or Black        NaN       NaN                     0
# 2       African American  or Black        NaN       NaN                     0
# 3               Caucasian or White        NaN       NaN                     0
# 4               Caucasian or White        NaN       NaN                     0
# ...                            ...        ...       ...                   ...
# 972842  African American  or Black        NaN       NaN                     0
# 972843  African American  or Black        NaN       NaN                     0
# 972844  African American  or Black        NaN       NaN                     0
# 972845          Caucasian or White        NaN       NaN                     0
# 972846          Caucasian or White        NaN       NaN                     0
#
#           subject_id_hadm_id  \
# 0       10000100_58594204243
# 1       10000562_60707883031
# 2       10000671_67252991505
# 3       10000683_29770490036
# 4       10000683_21514546148
# ...                      ...
# 972842  99999731_37382428249
# 972843  99999731_58311570862
# 972844  99999731_55258667078
# 972845  99999856_39743800534
# 972846  99999997_48836056566
#
#                                                long_title icd_code  \
# 0                                        Abscess of liver    K75.0
# 1                      Long term (current) use of insulin    Z79.4
# 2                                         Epigastric pain   R10.13
# 3                                            Not Recorded    272.4
# 4                                            Not Recorded   305.00
# ...                                                   ...      ...
# 972842                                       Not Recorded    585.9
# 972843                                       Not Recorded   255.42
# 972844                                       Not Recorded   276.51
# 972845                    Unspecified atrial fibrillation   I48.91
# 972846  Age-related osteoporosis without current patho...    M81.0
#
#        first_careunit last_careunit       los
# 0                 NaN           NaN       NaN
# 1                 NaN           NaN       NaN
# 2                 NaN           NaN       NaN
# 3          5E ICU EUH    5E ICU EUH  0.207338
# 4                 NaN           NaN       NaN
# ...               ...           ...       ...
# 972842            NaN           NaN       NaN
# 972843            NaN           NaN       NaN
# 972844            NaN           NaN       NaN
# 972845            NaN           NaN       NaN
# 972846            NaN           NaN       NaN
#
# [972847 rows x 22 columns]

# %% [markdown]
# ### We want to check the datatypes of each column of the dataframe.

# %%
df.dtypes
# Out:
# subject_id                int64
# hadm_id                   int64
# admittime                object
# dischtime                object
# deathtime                object
# admission_type          float64
# admit_provider_id       float64
# admission_location       object
# discharge_location       object
# insurance                object
# language                float64
# marital_status          float64
# race                     object
# edregtime               float64
# edouttime               float64
# hospital_expire_flag      int64
# subject_id_hadm_id       object
# long_title               object
# icd_code                 object
# first_careunit           object
# last_careunit            object
# los                     float64
# dtype: object

# %% [markdown]
# ### We see that some columns of the dataframe has no value/null values, so we are removing them (the columns).

# %%
## marital status and language have all null values, thus we are removing those columns
df=df.drop(["language","marital_status","admission_type","edregtime","edouttime"], axis=1)

# %% [markdown]
# #### ID columns are not needed because they are unique and will not contribute to the model building.

# %%
## id columns are also not needed
df=df.drop(["subject_id","hadm_id", "subject_id_hadm_id","admit_provider_id"], axis=1)

df.dtypes
# Out:
# admittime                object
# dischtime                object
# deathtime                object
# admission_location       object
# discharge_location       object
# insurance                object
# race                     object
# hospital_expire_flag      int64
# long_title               object
# icd_code                 object
# first_careunit           object
# last_careunit            object
# los                     float64
# dtype: object

# %% [markdown]
# ## Converting the date columns to Unix timestamp

# %% [markdown]
# #### In order to make the time columns readable and useful for the training, we are converting them to Unix timestamp.

# %% [markdown]
# Unix timestamp is a way to represent a specific point in time as a single integer. It counts the number of seconds that have elapsed since the Unix epoch, which is defined as 00:00:00 UTC on January 1, 1970.

# %%
# Convert the 'date' column to datetime format
df['admittime'] = pd.to_datetime(df['admittime'], errors='coerce')
df['dischtime'] = pd.to_datetime(df['dischtime'], errors='coerce')
df['deathtime'] = pd.to_datetime(df['deathtime'], errors='coerce')

# Convert the 'date' column to Unix timestamp (seconds since 1970-01-01)
#df['admittime'] = df['admittime'].astype('int64') // 10**9
#df['dischtime'] = df['dischtime'].astype('int64') // 10**9
#df['deathtime'] = df['deathtime'].astype('int64') // 10**9

# Define the initial timestamp (1970-01-01)
initial_timestamp = pd.Timestamp('1970-01-01').timestamp()

# Apply the conversion only if the value is not NaN
df['admittime'] = df['admittime'].apply(lambda x: int(x.timestamp() - initial_timestamp) if pd.notna(x) else np.nan)
df['dischtime'] = df['dischtime'].apply(lambda x: int(x.timestamp() - initial_timestamp) if pd.notna(x) else np.nan)
df['deathtime'] = df['deathtime'].apply(lambda x: int(x.timestamp() - initial_timestamp) if pd.notna(x) else np.nan)

# %% [markdown]
# #### Check how the time columns have changed-

# %%
df
# Out:
#          admittime   dischtime  deathtime   admission_location  \
# 0       1561555200  1562330820        NaN    PHYSIC OFC/CLINIC
# 1       1464859440  1465053060        NaN  NON-HC FACILITY POO
# 2       1557865200  1557925740        NaN  NON-HC FACILITY POO
# 3       1431455280  1431878100        NaN   TRANSFER FROM HOSP
# 4       1432821840  1433358180        NaN  NON-HC FACILITY POO
# ...            ...         ...        ...                  ...
# 972842  1259067000  1259175000        NaN         Not Recorded
# 972843  1277738580  1277840520        NaN  NON-HC FACILITY POO
# 972844  1290258060  1290365100        NaN  NON-HC FACILITY POO
# 972845  1569054000  1569253500        NaN  NON-HC FACILITY POO
# 972846  1518561840  1518706380        NaN  NON-HC FACILITY POO
#
#        discharge_location            insurance                        race  \
# 0          HOME SELF CARE           MEDICARE A  African American  or Black
# 1          HOME SELF CARE             MEDICAID  African American  or Black
# 2          HOME SELF CARE             SELF PAY  African American  or Black
# 3          HOME SELF CARE         MANAGED CARE          Caucasian or White
# 4          HOME SELF CARE         MANAGED CARE          Caucasian or White
# ...                   ...                  ...                         ...
# 972842     HOME SELF CARE         MANAGED CARE  African American  or Black
# 972843     HOME SELF CARE         MANAGED CARE  African American  or Black
# 972844     HOME SELF CARE         MANAGED CARE  African American  or Black
# 972845     HOME SELF CARE             MEDICARE          Caucasian or White
# 972846     HOME SELF CARE  MEDICARE/BLUE CROSS          Caucasian or White
#
#         hospital_expire_flag  \
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 972842                     0
# 972843                     0
# 972844                     0
# 972845                     0
# 972846                     0
#
#                                                long_title icd_code  \
# 0                                        Abscess of liver    K75.0
# 1                      Long term (current) use of insulin    Z79.4
# 2                                         Epigastric pain   R10.13
# 3                                            Not Recorded    272.4
# 4                                            Not Recorded   305.00
# ...                                                   ...      ...
# 972842                                       Not Recorded    585.9
# 972843                                       Not Recorded   255.42
# 972844                                       Not Recorded   276.51
# 972845                    Unspecified atrial fibrillation   I48.91
# 972846  Age-related osteoporosis without current patho...    M81.0
#
#        first_careunit last_careunit       los
# 0                 NaN           NaN       NaN
# 1                 NaN           NaN       NaN
# 2                 NaN           NaN       NaN
# 3          5E ICU EUH    5E ICU EUH  0.207338
# 4                 NaN           NaN       NaN
# ...               ...           ...       ...
# 972842            NaN           NaN       NaN
# 972843            NaN           NaN       NaN
# 972844            NaN           NaN       NaN
# 972845            NaN           NaN       NaN
# 972846            NaN           NaN       NaN
#
# [972847 rows x 13 columns]

# %% [markdown]
# #### Also, we are dropping those rows where we do not have any 'length of stay' value because that is our target variable.

# %%
df = df.dropna(subset=['los'])

# %%
df.dtypes
# Out:
# admittime                 int64
# dischtime                 int64
# deathtime               float64
# admission_location       object
# discharge_location       object
# insurance                object
# race                     object
# hospital_expire_flag      int64
# long_title               object
# icd_code                 object
# first_careunit           object
# last_careunit            object
# los                     float64
# dtype: object

# %% [markdown]
# ## Defining the categorical and numerical columns

# %% [markdown]
# As we build a regressor, we want to define the categorical and numerical columns, depending on what type data we have.

# %%
df = df.astype({'admission_location':'object',
                'discharge_location':'object',    
                'insurance':'object',                 
                'race':'object',                      
                'hospital_expire_flag':'object',      
                'long_title':'object',                
                'icd_code':'object',                  
                'first_careunit':'object',            
                'last_careunit':'object',
                'hospital_expire_flag': 'object'
               })

df.dtypes
# Out:
# admittime                 int64
# dischtime                 int64
# deathtime               float64
# admission_location       object
# discharge_location       object
# insurance                object
# race                     object
# hospital_expire_flag     object
# long_title               object
# icd_code                 object
# first_careunit           object
# last_careunit            object
# los                     float64
# dtype: object

# %%
# Identify categorical and numerical columns
categorical_cols = df.select_dtypes(include=['object']).columns
numeric_cols = df.select_dtypes(include=[np.number]).columns

# %%
categorical_cols
# Out:
# Index(['admission_location', 'discharge_location', 'insurance', 'race',
#        'hospital_expire_flag', 'long_title', 'icd_code', 'first_careunit',
#        'last_careunit'],
#       dtype='object')

# %%
numeric_cols
# Out:
# Index(['admittime', 'dischtime', 'deathtime', 'los'], dtype='object')

# %% [markdown]
# ### Starting with encoding the categorical variables

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Initialize the LabelEncoder
le = LabelEncoder()

# Apply LabelEncoder to each categorical column
for column in categorical_cols:
    df[column] = le.fit_transform(df[column])

# %%
df
# Out:
#          admittime   dischtime  deathtime  admission_location  \
# 3       1431455280  1431878100        NaN                  11
# 6       1441662180  1442334300        NaN                   4
# 8       1485927720  1487775240        NaN                   4
# 20      1348732320  1349883180        NaN                   4
# 21      1602891960  1604425440        NaN                  11
# ...            ...         ...        ...                 ...
# 972778  1293334020  1293987540        NaN                   4
# 972785  1431834120  1432075920        NaN                   4
# 972790  1523205540  1523364720        NaN                   4
# 972812  1505805240  1506278460        NaN                   4
# 972822  1616204100  1616682720        NaN                   4
#
#         discharge_location  insurance  race  hospital_expire_flag  long_title  \
# 3                       12         25     9                     0        3018
# 6                       12         25     9                     0        3018
# 8                       27         33     9                     0         468
# 20                      27         33     9                     0        3018
# 21                      12         33     3                     0        3528
# ...                    ...        ...   ...                   ...         ...
# 972778                  12         61     3                     0        3018
# 972785                  34         31     3                     0        3018
# 972790                  12         32     3                     0        2144
# 972812                  12         46     9                     0        3396
# 972822                  12         45     6                     0        3348
#
#         icd_code  first_careunit  last_careunit        los
# 3            543              21             19   0.207338
# 6           1512              21             19   1.096123
# 8           8585              11              9  10.840660
# 20           575              21             19   0.718866
# 21          5298              24             22   1.715903
# ...          ...             ...            ...        ...
# 972778         0              36              1   1.247905
# 972785      1602              17             15   1.323345
# 972790      4531              17             15   0.876887
# 972812      5101              11              9   1.113264
# 972822      4711              15             13   2.817430
#
# [172586 rows x 13 columns]

# %% [markdown]
# #### From now on, we will work on a randomized subset of the dataset.

# %% [markdown]
# ##### Here we are taking a fraction of the patients so that we work with ~10k patients for the training.

# %%
df_1=df

df = df.sample(frac=0.05795).reset_index(drop=True)

# %%
df
# Out:
#         admittime   dischtime  deathtime  admission_location  \
# 0      1295736600  1296844860        NaN                   4
# 1      1483694280  1483887240        NaN                   4
# 2      1416856080  1417105500        NaN                   4
# 3      1628921520  1629734340        NaN                  11
# 4      1419752880  1419962040        NaN                   4
# ...           ...         ...        ...                 ...
# 9996   1593010260  1593367800        NaN                   4
# 9997   1364988660  1368119460        NaN                   6
# 9998   1421164860  1421520000        NaN                  11
# 9999   1353003540  1353507540        NaN                  11
# 10000  1460689020  1461177900        NaN                   4
#
#        discharge_location  insurance  race  hospital_expire_flag  long_title  \
# 0                      11         15     9                     1        3018
# 1                      12         33     9                     0        2058
# 2                      12         31     3                     0        3018
# 3                      12          4     9                     0        3345
# 4                      12         31     3                     0        3018
# ...                   ...        ...   ...                   ...         ...
# 9996                   11         45     9                     1         628
# 9997                   11         25     9                     1        3018
# 9998                   12         31     9                     0        3018
# 9999                   12         31    15                     0        3018
# 10000                  12          0     9                     0        2415
#
#        icd_code  first_careunit  last_careunit       los
# 0           858              21             19  2.110579
# 1          5520              22             20  2.112049
# 2          7990              27             25  0.576273
# 3          5903               5              3  5.218901
# 4           461              28             26  1.059109
# ...         ...             ...            ...       ...
# 9996       4557              23             21  1.824849
# 9997       1237              19             17  9.613576
# 9998        897               7              3  3.886528
# 9999        461              36              0  1.896377
# 10000      8673              21             19  1.191447
#
# [10001 rows x 13 columns]

# %% [markdown]
# #### We need more libraries for further preprocessing and build the model.

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# #### We also want to do correlation test on the dataset to see if there is any variable which is highly correlated.

# %%
correlation_matrix = df.corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                       admittime  dischtime  deathtime  admission_location  \
# admittime              1.000000   0.999944   0.999848           -0.006714
# dischtime              0.999944   1.000000   0.999999           -0.005294
# deathtime              0.999848   0.999999   1.000000            0.285596
# admission_location    -0.006714  -0.005294   0.285596            1.000000
# discharge_location    -0.002819  -0.000766        NaN            0.129037
# insurance              0.027658   0.027525  -0.606527            0.023561
# race                  -0.014926  -0.014987   0.120935            0.132919
# hospital_expire_flag  -0.089071  -0.088136        NaN            0.048672
# long_title            -0.194980  -0.195021  -0.339229           -0.011382
# icd_code               0.544626   0.544489   0.529864           -0.014906
# first_careunit        -0.105264  -0.104995   0.118022           -0.123086
# last_careunit         -0.018101  -0.017758   0.456907           -0.151180
# los                    0.031586   0.037415   0.534244            0.126193
#
#                       discharge_location  insurance      race  \
# admittime                      -0.002819   0.027658 -0.014926
# dischtime                      -0.000766   0.027525 -0.014987
# deathtime                            NaN  -0.606527  0.120935
# admission_location              0.129037   0.023561  0.132919
# discharge_location              1.000000   0.034031 -0.001536
# insurance                       0.034031   1.000000  0.002357
# race                           -0.001536   0.002357  1.000000
# hospital_expire_flag           -0.085542   0.033723 -0.038142
# long_title                      0.012933  -0.019014  0.006980
# icd_code                       -0.002589   0.028571  0.008474
# first_careunit                 -0.003983  -0.007482 -0.119757
# last_careunit                  -0.001522   0.006653 -0.140796
# los                             0.080602  -0.033349  0.012522
#
#                       hospital_expire_flag  long_title  icd_code  \
# admittime                        -0.089071   -0.194980  0.544626
# dischtime                        -0.088136   -0.195021  0.544489
# deathtime                              NaN   -0.339229  0.529864
# admission_location                0.048672   -0.011382 -0.014906
# discharge_location               -0.085542    0.012933 -0.002589
# insurance                         0.033723   -0.019014  0.028571
# race                             -0.038142    0.006980  0.008474
# hospital_expire_flag              1.000000   -0.003069 -0.041165
# long_title                       -0.003069    1.000000 -0.149038
# icd_code                         -0.041165   -0.149038  1.000000
# first_careunit                    0.073980    0.021503 -0.035984
# last_careunit                     0.091184    0.001145  0.013516
# los                               0.101799   -0.006272 -0.000031
#
#                       first_careunit  last_careunit       los
# admittime                  -0.105264      -0.018101  0.031586
# dischtime                  -0.104995      -0.017758  0.037415
# deathtime                   0.118022       0.456907  0.534244
# admission_location         -0.123086      -0.151180  0.126193
# discharge_location         -0.003983      -0.001522  0.080602
# insurance                  -0.007482       0.006653 -0.033349
# race                       -0.119757      -0.140796  0.012522
# hospital_expire_flag        0.073980       0.091184  0.101799
# long_title                  0.021503       0.001145 -0.006272
# icd_code                   -0.035984       0.013516 -0.000031
# first_careunit              1.000000       0.877196 -0.020146
# last_careunit               0.877196       1.000000 -0.005236
# los                        -0.020146      -0.005236  1.000000

# %% [markdown]
# #### We can see the correlation matrix as heatmap.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Set the title
plt.title('Correlation Matrix Heatmap', fontsize=16)

# Display the heatmap
plt.show()

# %% [markdown]
# #### To improve the accuracy of our model, we want to delete the highly correlated features from the dataframe.

# %%
# Set a threshold for removing highly correlated variables
threshold = 0.9

# Create a boolean mask for the upper triangle of the correlation matrix
upper_triangle = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))

# Find index pairs of highly correlated variables
to_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > threshold)]

# Drop the highly correlated columns from the DataFrame
df_reduced = df.drop(columns=to_drop)

# Display the columns that were dropped
print(f"Dropped columns: {to_drop}")
# Out:
# Dropped columns: ['dischtime', 'deathtime']

# %%
df = df_reduced

# %%
df
# Out:
#         admittime  admission_location  discharge_location  insurance  race  \
# 0      1295736600                   4                  11         15     9
# 1      1483694280                   4                  12         33     9
# 2      1416856080                   4                  12         31     3
# 3      1628921520                  11                  12          4     9
# 4      1419752880                   4                  12         31     3
# ...           ...                 ...                 ...        ...   ...
# 9996   1593010260                   4                  11         45     9
# 9997   1364988660                   6                  11         25     9
# 9998   1421164860                  11                  12         31     9
# 9999   1353003540                  11                  12         31    15
# 10000  1460689020                   4                  12          0     9
#
#        hospital_expire_flag  long_title  icd_code  first_careunit  \
# 0                         1        3018       858              21
# 1                         0        2058      5520              22
# 2                         0        3018      7990              27
# 3                         0        3345      5903               5
# 4                         0        3018       461              28
# ...                     ...         ...       ...             ...
# 9996                      1         628      4557              23
# 9997                      1        3018      1237              19
# 9998                      0        3018       897               7
# 9999                      0        3018       461              36
# 10000                     0        2415      8673              21
#
#        last_careunit       los
# 0                 19  2.110579
# 1                 20  2.112049
# 2                 25  0.576273
# 3                  3  5.218901
# 4                 26  1.059109
# ...              ...       ...
# 9996              21  1.824849
# 9997              17  9.613576
# 9998               3  3.886528
# 9999               0  1.896377
# 10000             19  1.191447
#
# [10001 rows x 11 columns]

# %% [markdown]
# ## Split Data into Features and Target

# %% [markdown]
# #### We are splitting the subset data into features and target.

# %%
X = df.drop('los', axis=1)
y = df['los']

# %% [markdown]
# ### After removing highly correlated features, we want apply standard scaling to the remaining features.

# %%
#Scale the Data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#Split the Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
#Build and Train  Model
model = HistGradientBoostingRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# HistGradientBoostingRegressor(random_state=42)

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# We want to see which features are most important and which are not. If we find a feature is not much important in predicting the los, we will remove it.

# %% [markdown]
# As HistGradientBoostingRegressor does not have the feature_importances_ function in it, we will use permutation_importance function. This method works by shuffling each feature and measuring how much the model’s performance decreases.

# %%
from sklearn.inspection import permutation_importance

# Perform permutation importance
perm_importance = permutation_importance(model, X_test, y_test, n_repeats=10, random_state=42)

# Get the importance scores
importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': perm_importance.importances_mean
})

# Sort the features by importance
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importance
plt.figure(figsize=(10, 8))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance (Permutation Importance)')
plt.gca().invert_yaxis()  # Invert the y-axis to have the most important feature at the top
plt.show()

# %% [markdown]
# ### We can remove less important features from the dataframe.

# %%
X = df.drop(['hospital_expire_flag', 'admission_location', 'race', 'insurance', 'los'], axis=1)
y = df['los']

# %%
#Scale the Data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#Split the Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
#Build and Train  Model
model = HistGradientBoostingRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# HistGradientBoostingRegressor(random_state=42)

# %%
# Evaluate the Model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)

# %%
mse
# Out:
# np.float64(30.98779479767044)

# %% [markdown]
# Further, we can look into Overfitting. It occurs when a model fits the training data too closely, capturing noise rather than patterns, leading to poor performance on new data. It can be caused by complex models, small datasets, or noisy data.
#
# To prevent it, we can simplify the model and apply cross-validation. For HistGradientBoostingRegressor, adjusting hyperparameters and using cross-validation are effective strategies.

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'max_iter': [100, 200, 300],
    'max_leaf_nodes': [20, 50, 100],
    'learning_rate': [0.01, 0.1, 0.2]
}

# Initialize the model
model = HistGradientBoostingRegressor(random_state=42)

# Setup GridSearchCV
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(X, y)

# Print the best parameters and score
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Score: {-grid_search.best_score_:.4f}")

# Get the best model
best_model = grid_search.best_estimator_
# Out:
# Best Parameters: {'learning_rate': 0.01, 'max_iter': 300, 'max_leaf_nodes': 20}
# Best Score: 51.9475

# %% [markdown]
# ### Now let's train the best model from Grid Search and see the score.

# %%
# Get the best model from GridSearchCV
best_model = grid_search.best_estimator_

# Train the best model on the entire training data (if not already done)
best_model.fit(X_train, y_train)
# Out:
# HistGradientBoostingRegressor(learning_rate=0.01, max_iter=300,
#                               max_leaf_nodes=20, random_state=42)

# %%
# Predict on the test set
y_pred = best_model.predict(X_test)

# Calculate the mean squared error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error on Test Set: {mse:.4f}")
# Out:
# Mean Squared Error on Test Set: 28.9405
